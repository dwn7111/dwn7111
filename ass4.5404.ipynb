# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg as la
from PIL import Image as im

# %%
# Question 2a
pic = im.open(r'C:\Users\Shwetabh\Documents\Uni\Masters\Sem 2\5404\hw4\rose.jpg')
pic.show()

# %%
# Question 2a
A = plt.imread(r'C:\Users\Shwetabh\Documents\Uni\Masters\Sem 2\5404\hw4\rose.jpg')
plt.imshow(A)
plt.show()

# %%
# Question 2b
U, s, V = la.svd(A)
bigno = s[0:100]
plt.plot(bigno)
plt.show()

# %%
#Question 2C
r = [1,5,20,50,100]
for i in r:
    Anew = U[:, :i]@ np.diag(s[:i]) @ V[:i, :]  
    plt.imshow(Anew)
    plt.title("r = %s" % i)
    plt.show()
